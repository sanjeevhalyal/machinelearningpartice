# %%
from transformers import pipeline

# %%
zs = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 zs = pipeline("zero-shot-classification")
#
# File ~/.conda/envs/MachineLearning-3.8/lib/python3.8/site-packages/transformers/pipelines/__init__.py:567, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, model_kwargs, pipeline_class, **kwargs)
#     563 # Infer the framework from the model
#     564 # Forced if framework already defined, inferred if it's None
#     565 # Will load the correct model if possible
#     566 model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# ...
